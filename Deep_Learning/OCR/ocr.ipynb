# %% [markdown]
# ## Import necessary libraries

# %%
import cv2
import pytesseract
import matplotlib.pyplot as plt
import time

# %% [markdown]
# ## Load the image

# %%
img=cv2.imread("D:\Artificial_Intelligence\CHRISTY_SIR\OCR\images 2.jpg")

# %% [markdown]
# ## Display the image

# %%
plt.imshow(img)

# %% [markdown]
# ## Introducing time library
# (Learning purpose)

# %%
# start=time.time()   # float value
start=time.time_ns()  # int value
start2=time.ctime()
start2
# Out:
# 'Tue Mar 14 08:04:23 2023'

# %% [markdown]
# ## Convert image to string using pytesseract

# %%
text=pytesseract.image_to_string(img)
print(text)
# Out:
# Dies ist ein Blindtext. An ihm lasst sich
# vieles tiber die Schrift ablesen, in der er ge-
# setzt ist. Auf den ersten Blick wird der
# Grauwert der Schriftflache sichtbar. Dann
# kann man prifen, wie gut die Schrift zu
# lesen ist und wie sie auf den Leser wirkt.
# Dies ist ein Blindtext. An ihm lasst sich
# vieles tiber die Schrift ablesen, in der er ge-
# setzt ist. Auf den ersten Blick wird der
# Grauwert der Schriftflache sichtbar. Dann
# kann man prifen, wie gut die Schrift zu
# lesen ist und wie sie auf den Leser wirkt.
